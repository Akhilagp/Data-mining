# %%
import pandas as pd
import numpy as np

# %%
fil = pd.read_csv('sleep.csv')
fil.shape
# Out:
# (134, 20)

# %%
fil.head(5)
# Out:
#                         Timestamp Can we know your name please?  Your age  \
# 0  2019/02/02 5:14:51 PM GMT+5:30                           NaN        20
# 1  2019/02/02 5:24:09 PM GMT+5:30                   _AP_The_Don        20
# 2  2019/02/02 5:32:44 PM GMT+5:30                         Riyaz        20
# 3  2019/02/02 5:33:13 PM GMT+5:30                           NaN        20
# 4  2019/02/02 5:34:00 PM GMT+5:30       Hussain Imthiaz Hussain        17
#
#   What is your typical time to go to sleep?  \
# 0                             10 pm - 12 am
# 1                             10 pm - 12 am
# 2                             10 pm - 12 am
# 3                                      1 am
# 4                              Before 10 pm
#
#   Average number of hours of sleep per night  \
# 0                                        5-6
# 1                                        7-8
# 2                                        5-6
# 3                                        7-8
# 4                                        7-8
#
#   How long does it take you to fall asleep after being in bed (Scaled in minutes)?  \
# 0                                            31 - 45
# 1                                             0 - 15
# 2                                             0 - 15
# 3                                             0 - 15
# 4                                             0 - 15
#
#   How many times ﻿do you wake up in between sleep?  \
# 0                                               <2
# 1                                               <2
# 2                                               <2
# 3                                               <2
# 4                                               <2
#
#   Do you uncontrollably feel sleepy during the day/ class hours?  \
# 0                                            Usually
# 1                                             Always
# 2                                             Always
# 3                                          Sometimes
# 4                                             Rarely
#
#   Do you use any fitness / sleep tracking device?  \
# 0                                              No
# 1                                             Yes
# 2                                              No
# 3                                              No
# 4                                              No
#
#   Sleep Environment [Do you watch TV/ use Mobile phones prior to sleep?]  \
# 0                                          Sometimes
# 1                                                Yes
# 2                                                Yes
# 3                                          Sometimes
# 4                                          Sometimes
#
#   Sleep Environment [Do you sleep alone?]  \
# 0                                   Never
# 1                                     Yes
# 2                                     Yes
# 3                                     Yes
# 4                                   Never
#
#   Sleep Environment [Is your study and sleep space separate?]  \
# 0                                          Sometimes
# 1                                              Never
# 2                                                Yes
# 3                                          Sometimes
# 4                                              Never
#
#    How comfortable is your sleep area?  \
# 0                                    3
# 1                                    2
# 2                                    5
# 3                                    5
# 4                                    4
#
#   Does your sleeping habits affect your mood / academic performance / performance at work ?  \
# 0                                          Sometimes
# 1                                            Usually
# 2                                              Never
# 3                                            Usually
# 4                                             Always
#
#   Insomnia [Do you have trouble falling sleep?]  \
# 0                                        Seldom
# 1                                            No
# 2                                            No
# 3                                            No
# 4                                        Seldom
#
#   Insomnia [Do you have trouble returning to sleep after being awaken during the night?]  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                          Sometimes
#
#   Insomnia [Do you use medications to help you sleep?]  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                             Seldom
#
#   Is your sleep routine consistent ?  How would you rate your sleep?  Gender
# 0                   Only on weekdays                               3  Female
# 1                                 No                               4    Male
# 2                                Yes                               4    Male
# 3                   Only on weekdays                               4     NaN
# 4                                Yes                               4    Male

# %%
drop_cols = fil.columns.values[0:2]
fil=fil.drop(columns=drop_cols)
fil.shape
# Out:
# (134, 18)

# %%
print fil.columns.values
# Out:
# ['Your age' 'What is your typical time to go to sleep?'
#  'Average number of hours of sleep per night'
#  'How long does it take you to fall asleep after being in bed (Scaled in minutes)?'
#  'How many times \xef\xbb\xbfdo you wake up in between sleep?'
#  'Do you uncontrollably feel sleepy during the day/ class hours?'
#  'Do you use any fitness / sleep tracking device?'
#  'Sleep Environment [Do you watch TV/ use Mobile phones prior to sleep?]'
#  'Sleep Environment [Do you sleep alone?]'
#  'Sleep Environment [Is your study and sleep space separate?]'
#  'How comfortable is your sleep area?'
#  'Does your sleeping habits affect your mood / academic performance / performance at work ?'
#  'Insomnia [Do you have trouble falling sleep?]'
#  'Insomnia [Do you have trouble returning to sleep after being awaken during the night?]'
#  'Insomnia [Do you use medications to help you sleep?]'
#  'Is your sleep routine consistent ?' 'How would you rate your sleep?'
#  'Gender']

# %%
fil.columns = ['age','time_sleep','no_of_hrs','minutes_to_sleep','wake_up','day_sleep','tracker','use_tv','sleep_alone','sep_sleep_place','comfort','perf','trouble_sleep','trouble_back_to_sleep','medication','routine','rate','gender']

# %%
fil.columns.values
fil.shape
# Out:
# (134, 18)

# %%
fil.columns.values
# Out:
# array(['age', 'time_sleep', 'no_of_hrs', 'minutes_to_sleep', 'wake_up',
#        'day_sleep', 'tracker', 'use_tv', 'sleep_alone', 'sep_sleep_place',
#        'comfort', 'perf', 'trouble_sleep', 'trouble_back_to_sleep',
#        'medication', 'routine', 'rate', 'gender'], dtype=object)

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort       perf trouble_sleep  \
# 0  Sometimes       Never       Sometimes        3  Sometimes        Seldom
# 1        Yes         Yes           Never        2    Usually            No
# 2        Yes         Yes             Yes        5      Never            No
# 3  Sometimes         Yes       Sometimes        5    Usually            No
# 4  Sometimes       Never           Never        4     Always        Seldom
#
#   trouble_back_to_sleep medication           routine  rate  gender
# 0                    No         No  Only on weekdays     3  Female
# 1                    No         No                No     4    Male
# 2                    No         No               Yes     4    Male
# 3                    No         No  Only on weekdays     4     NaN
# 4             Sometimes     Seldom               Yes     4    Male

# %%
fil['gender'].fillna('Untold',inplace=True)

# %%
fil['gender']=np.where(fil['gender']=='Male',0,fil['gender'])
fil['gender']=np.where(fil['gender']=='Female',1,fil['gender'])
fil['gender']=np.where(fil['gender']=='Untold',2,fil['gender'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-009b6eb614c9> in <module>()
# ----> 1 fil[np.where(fil['gender'=='Male'])]=0
#       2 fil[np.where(fil['gender']=='Female')]=1
#       3 fil[np.where(fil['gender']=='Untold')]=2
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort       perf trouble_sleep  \
# 0  Sometimes       Never       Sometimes        3  Sometimes        Seldom
# 1        Yes         Yes           Never        2    Usually            No
# 2        Yes         Yes             Yes        5      Never            No
# 3  Sometimes         Yes       Sometimes        5    Usually            No
# 4  Sometimes       Never           Never        4     Always        Seldom
#
#   trouble_back_to_sleep medication           routine  rate gender
# 0                    No         No  Only on weekdays     3      1
# 1                    No         No                No     4      0
# 2                    No         No               Yes     4      0
# 3                    No         No  Only on weekdays     4      2
# 4             Sometimes     Seldom               Yes     4      0

# %%
fil['routine']=np.where(fil['routine']=='Yes',0,fil['routine'])
fil['routine']=np.where(fil['routine']=='Only on weekdays',1,fil['routine'])
fil['routine']=np.where(fil['routine']=='No',2,fil['routine'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort       perf trouble_sleep  \
# 0  Sometimes       Never       Sometimes        3  Sometimes        Seldom
# 1        Yes         Yes           Never        2    Usually            No
# 2        Yes         Yes             Yes        5      Never            No
# 3  Sometimes         Yes       Sometimes        5    Usually            No
# 4  Sometimes       Never           Never        4     Always        Seldom
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                    No         No       1     3      1
# 1                    No         No       2     4      0
# 2                    No         No       0     4      0
# 3                    No         No       1     4      2
# 4             Sometimes     Seldom       0     4      0

# %%
fil['medication']=np.where(fil['medication']=='Yes',0,fil['medication'])
fil['medication']=np.where(fil['medication']=='Sometimes',1,fil['medication'])
fil['medication']=np.where(fil['medication']=='Seldom',2,fil['medication'])
fil['medication']=np.where(fil['medication']=='No',3,fil['medication'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort       perf trouble_sleep  \
# 0  Sometimes       Never       Sometimes        3  Sometimes        Seldom
# 1        Yes         Yes           Never        2    Usually            No
# 2        Yes         Yes             Yes        5      Never            No
# 3  Sometimes         Yes       Sometimes        5    Usually            No
# 4  Sometimes       Never           Never        4     Always        Seldom
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                    No          3       1     3      1
# 1                    No          3       2     4      0
# 2                    No          3       0     4      0
# 3                    No          3       1     4      2
# 4             Sometimes          2       0     4      0

# %%
fil.dtypes
# Out:
# age                       int64
# time_sleep               object
# no_of_hrs                object
# minutes_to_sleep         object
# wake_up                  object
# day_sleep                object
# tracker                  object
# use_tv                   object
# sleep_alone              object
# sep_sleep_place          object
# comfort                   int64
# perf                     object
# trouble_sleep            object
# trouble_back_to_sleep    object
# medication               object
# routine                  object
# rate                      int64
# gender                   object
# dtype: object

# %%
fil['trouble_back_to_sleep']=np.where(fil['trouble_back_to_sleep']=='Yes',0,fil['trouble_back_to_sleep'])
fil['trouble_back_to_sleep']=np.where(fil['trouble_back_to_sleep']=='Sometimes',1,fil['trouble_back_to_sleep'])
fil['trouble_back_to_sleep']=np.where(fil['trouble_back_to_sleep']=='Seldom',2,fil['trouble_back_to_sleep'])
fil['trouble_back_to_sleep']=np.where(fil['trouble_back_to_sleep']=='No',3,fil['trouble_back_to_sleep'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort       perf trouble_sleep  \
# 0  Sometimes       Never       Sometimes        3  Sometimes        Seldom
# 1        Yes         Yes           Never        2    Usually            No
# 2        Yes         Yes             Yes        5      Never            No
# 3  Sometimes         Yes       Sometimes        5    Usually            No
# 4  Sometimes       Never           Never        4     Always        Seldom
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['trouble_sleep']=np.where(fil['trouble_sleep']=='Yes',0,fil['trouble_sleep'])
fil['trouble_sleep']=np.where(fil['trouble_sleep']=='Sometimes',1,fil['trouble_sleep'])
fil['trouble_sleep']=np.where(fil['trouble_sleep']=='Seldom',2,fil['trouble_sleep'])
fil['trouble_sleep']=np.where(fil['trouble_sleep']=='No',3,fil['trouble_sleep'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort       perf trouble_sleep  \
# 0  Sometimes       Never       Sometimes        3  Sometimes             2
# 1        Yes         Yes           Never        2    Usually             3
# 2        Yes         Yes             Yes        5      Never             3
# 3  Sometimes         Yes       Sometimes        5    Usually             3
# 4  Sometimes       Never           Never        4     Always             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['perf']=np.where(fil['perf']=='Always',0,fil['perf'])
fil['perf']=np.where(fil['perf']=='Usually',1,fil['perf'])
fil['perf']=np.where(fil['perf']=='Sometimes',2,fil['perf'])
fil['perf']=np.where(fil['perf']=='Never',3,fil['perf'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0  Sometimes       Never       Sometimes        3    2             2
# 1        Yes         Yes           Never        2    1             3
# 2        Yes         Yes             Yes        5    3             3
# 3  Sometimes         Yes       Sometimes        5    1             3
# 4  Sometimes       Never           Never        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['sep_sleep_place']=np.where(fil['sep_sleep_place']=='Yes',0,fil['sep_sleep_place'])
fil['sep_sleep_place']=np.where(fil['sep_sleep_place']=='Sometimes',1,fil['sep_sleep_place'])
fil['sep_sleep_place']=np.where(fil['sep_sleep_place']=='Never',2,fil['sep_sleep_place'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0  Sometimes       Never               1        3    2             2
# 1        Yes         Yes               2        2    1             3
# 2        Yes         Yes               0        5    3             3
# 3  Sometimes         Yes               1        5    1             3
# 4  Sometimes       Never               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['sleep_alone']=np.where(fil['sleep_alone']=='Yes',0,fil['sleep_alone'])
fil['sleep_alone']=np.where(fil['sleep_alone']=='Sometimes',1,fil['sleep_alone'])
fil['sleep_alone']=np.where(fil['sleep_alone']=='Never',2,fil['sleep_alone'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#       use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0  Sometimes           2               1        3    2             2
# 1        Yes           0               2        2    1             3
# 2        Yes           0               0        5    3             3
# 3  Sometimes           0               1        5    1             3
# 4  Sometimes           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['use_tv']=np.where(fil['use_tv']=='Yes',0,fil['use_tv'])
fil['use_tv']=np.where(fil['use_tv']=='Sometimes',1,fil['use_tv'])
fil['use_tv']=np.where(fil['use_tv']=='Never',2,fil['use_tv'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually      No
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always     Yes
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always      No
# 3   20           1 am       7-8           0 - 15      <2  Sometimes      No
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely      No
#
#   use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0      1           2               1        3    2             2
# 1      0           0               2        2    1             3
# 2      0           0               0        5    3             3
# 3      1           0               1        5    1             3
# 4      1           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['tracker']=np.where(fil['tracker']=='Yes',0,fil['tracker'])
fil['tracker']=np.where(fil['tracker']=='No',1,fil['tracker'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up  day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2    Usually       1
# 1   20  10 pm - 12 am       7-8           0 - 15      <2     Always       0
# 2   20  10 pm - 12 am       5-6           0 - 15      <2     Always       1
# 3   20           1 am       7-8           0 - 15      <2  Sometimes       1
# 4   17   Before 10 pm       7-8           0 - 15      <2     Rarely       1
#
#   use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0      1           2               1        3    2             2
# 1      0           0               2        2    1             3
# 2      0           0               0        5    3             3
# 3      1           0               1        5    1             3
# 4      1           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['day_sleep']=np.where(fil['day_sleep']=='Always',0,fil['day_sleep'])
fil['day_sleep']=np.where(fil['day_sleep']=='Usually',1,fil['day_sleep'])
fil['day_sleep']=np.where(fil['day_sleep']=='Sometimes',2,fil['day_sleep'])
fil['day_sleep']=np.where(fil['day_sleep']=='Rarely',3,fil['day_sleep'])
fil['day_sleep']=np.where(fil['day_sleep']=='Never',4,fil['day_sleep'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45      <2         1       1
# 1   20  10 pm - 12 am       7-8           0 - 15      <2         0       0
# 2   20  10 pm - 12 am       5-6           0 - 15      <2         0       1
# 3   20           1 am       7-8           0 - 15      <2         2       1
# 4   17   Before 10 pm       7-8           0 - 15      <2         3       1
#
#   use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0      1           2               1        3    2             2
# 1      0           0               2        2    1             3
# 2      0           0               0        5    3             3
# 3      1           0               1        5    1             3
# 4      1           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['wake_up']=np.where(fil['wake_up']=='<2',0,fil['wake_up'])
fil['wake_up']=np.where(fil['wake_up']=='3',1,fil['wake_up'])
fil['wake_up']=np.where(fil['wake_up']=='4',2,fil['wake_up'])
fil['wake_up']=np.where(fil['wake_up']=='5',3,fil['wake_up'])
fil['wake_up']=np.where(fil['wake_up']=='>5',4,fil['wake_up'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6          31 - 45       0         1       1
# 1   20  10 pm - 12 am       7-8           0 - 15       0         0       0
# 2   20  10 pm - 12 am       5-6           0 - 15       0         0       1
# 3   20           1 am       7-8           0 - 15       0         2       1
# 4   17   Before 10 pm       7-8           0 - 15       0         3       1
#
#   use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0      1           2               1        3    2             2
# 1      0           0               2        2    1             3
# 2      0           0               0        5    3             3
# 3      1           0               1        5    1             3
# 4      1           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['minutes_to_sleep']=np.where(fil['minutes_to_sleep']=='0 - 15',0,fil['minutes_to_sleep'])
fil['minutes_to_sleep']=np.where(fil['minutes_to_sleep']=='16 - 30',1,fil['minutes_to_sleep'])
fil['minutes_to_sleep']=np.where(fil['minutes_to_sleep']=='31 - 45',2,fil['minutes_to_sleep'])
fil['minutes_to_sleep']=np.where(fil['minutes_to_sleep']=='46 - 60',3,fil['minutes_to_sleep'])
fil['minutes_to_sleep']=np.where(fil['minutes_to_sleep']=='>60',4,fil['minutes_to_sleep'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up day_sleep tracker  \
# 0   20  10 pm - 12 am       5-6                2       0         1       1
# 1   20  10 pm - 12 am       7-8                0       0         0       0
# 2   20  10 pm - 12 am       5-6                0       0         0       1
# 3   20           1 am       7-8                0       0         2       1
# 4   17   Before 10 pm       7-8                0       0         3       1
#
#   use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0      1           2               1        3    2             2
# 1      0           0               2        2    1             3
# 2      0           0               0        5    3             3
# 3      1           0               1        5    1             3
# 4      1           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['no_of_hrs']=np.where(fil['no_of_hrs']=='<=4',0,fil['no_of_hrs'])
fil['no_of_hrs']=np.where(fil['no_of_hrs']=='5-6',1,fil['no_of_hrs'])
fil['no_of_hrs']=np.where(fil['no_of_hrs']=='7-8',2,fil['no_of_hrs'])
fil['no_of_hrs']=np.where(fil['no_of_hrs']=='>8',3,fil['no_of_hrs'])

# %%
fil.head(5)
# Out:
#    age     time_sleep no_of_hrs minutes_to_sleep wake_up day_sleep tracker  \
# 0   20  10 pm - 12 am         1                2       0         1       1
# 1   20  10 pm - 12 am         2                0       0         0       0
# 2   20  10 pm - 12 am         1                0       0         0       1
# 3   20           1 am         2                0       0         2       1
# 4   17   Before 10 pm         2                0       0         3       1
#
#   use_tv sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0      1           2               1        3    2             2
# 1      0           0               2        2    1             3
# 2      0           0               0        5    3             3
# 3      1           0               1        5    1             3
# 4      1           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil['time_sleep']=np.where(fil['time_sleep']=='Before 10 pm',0,fil['time_sleep'])
fil['time_sleep']=np.where(fil['time_sleep']=='10 pm - 12 am',1,fil['time_sleep'])
fil['time_sleep']=np.where(fil['time_sleep']=='1 am',2,fil['time_sleep'])
fil['time_sleep']=np.where(fil['time_sleep']=='After 1 am',3,fil['time_sleep'])

# %%
fil.head(5)
# Out:
#    age time_sleep no_of_hrs minutes_to_sleep wake_up day_sleep tracker use_tv  \
# 0   20          1         1                2       0         1       1      1
# 1   20          1         2                0       0         0       0      0
# 2   20          1         1                0       0         0       1      0
# 3   20          2         2                0       0         2       1      1
# 4   17          0         2                0       0         3       1      1
#
#   sleep_alone sep_sleep_place  comfort perf trouble_sleep  \
# 0           2               1        3    2             2
# 1           0               2        2    1             3
# 2           0               0        5    3             3
# 3           0               1        5    1             3
# 4           2               2        4    0             2
#
#   trouble_back_to_sleep medication routine  rate gender
# 0                     3          3       1     3      1
# 1                     3          3       2     4      0
# 2                     3          3       0     4      0
# 3                     3          3       1     4      2
# 4                     1          2       0     4      0

# %%
fil.dtypes
# Out:
# age                       int64
# time_sleep               object
# no_of_hrs                object
# minutes_to_sleep         object
# wake_up                  object
# day_sleep                object
# tracker                  object
# use_tv                   object
# sleep_alone              object
# sep_sleep_place          object
# comfort                   int64
# perf                     object
# trouble_sleep            object
# trouble_back_to_sleep    object
# medication               object
# routine                  object
# rate                      int64
# gender                   object
# dtype: object

# %%
for i in fil.columns.values:
        fil[i]=fil[i].apply(pd.to_numeric)

# %%
fil.dtypes
# Out:
# age                      int64
# time_sleep               int64
# no_of_hrs                int64
# minutes_to_sleep         int64
# wake_up                  int64
# day_sleep                int64
# tracker                  int64
# use_tv                   int64
# sleep_alone              int64
# sep_sleep_place          int64
# comfort                  int64
# perf                     int64
# trouble_sleep            int64
# trouble_back_to_sleep    int64
# medication               int64
# routine                  int64
# rate                     int64
# gender                   int64
# dtype: object

# %%
temp=fil
temp1=fil
temp2=fil
fil.to_csv('sleep_cleaned.csv',index=False)

# %%
for i in temp.columns.values:
    temp[i] = temp[i] - temp[i].min(axis=0)
    temp[i] = temp[i]/(temp[i].max(axis=0)-temp[i].min(axis=0))

# %%
temp.shape
temp.to_csv('sleep_norm_min.csv',index=False)

# %%
for i in temp1.columns.values:
    temp1[i] = temp1[i] - temp1[i].max(axis=0)
    temp1[i] = temp[i]/(temp[i].max(axis=0)-temp[i].min(axis=0))

# %%
temp1.shape
temp1.to_csv('sleep_norm_max.csv',index=False)

# %%
for i in temp2.columns.values:
    temp2[i] = temp[i] - temp[i].mean(axis=0)
    temp2[i] = temp[i]/(temp[i].var(axis=0))

# %%
temp1.shape
temp1.to_csv('sleep_norm_var.csv',index=False)
